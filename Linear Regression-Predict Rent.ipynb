# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model

# %%
#Load data
data= pd.read_csv("OMIS1.csv")

# %%
data.head()
# Out:
#    Year of Experience   Salaries
# 0                  3.0      5000
# 1                  5.0      6500
# 2                  6.0      7200
# 3                  4.0      5800
# 4                 10.0     10700

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year of Experience   17 non-null     float64
#  1   Salaries             17 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 404.0 bytes

# %%
data.describe()
# Out:
#        Year of Experience       Salaries
# count            17.000000     17.000000
# mean              4.635294   6150.000000
# std               2.590594   2113.793982
# min               0.800000   1950.000000
# 25%               3.000000   4950.000000
# 50%               4.000000   5900.000000
# 75%               6.000000   7200.000000
# max              10.000000  10700.000000

# %%
data.columns
# Out:
# Index(['Year of Experience ', 'Salaries'], dtype='object')

# %%
# let us define features (x) and target (y)
# y = b1x1 + b2x2 +.....
y= data['Salaries']
x= data[['Year of Experience ']]

# %%
plt.scatter(x,y, color='green')
plt.xlabel('Year of Experience')
plt.ylabel('Salaries')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y ,test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
#     Year of Experience
# 13                  0.8
# 4                  10.0
# 2                   6.0
# 14                  3.0
# 10                  5.0
# 7                   4.0
# 16                  5.0
# 11                  2.0
# 3                   4.0
# 0                   3.0
# 5                   8.0
# 15                  4.0
# 12                  1.0

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict([[3], [4], [0.8],[10]])
# Out:
# array([ 4816.65667616,  5651.98186723,  2978.94125581, 10663.93301364])

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([6487.30705829, 7322.63224936, 4816.65667616, 9828.60782257])

# %%
#step 4
error= y_pred-y_test
error
# Out:
# 1    -12.692942
# 6    -27.367751
# 8   -133.343324
# 9    728.607823
# Name: Salaries, dtype: float64

# %%
#Visualize
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color="red")

# %%
#Measure accuracy
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R² score:", r2)
# Out:
# R² score: 0.9388188248632916
